# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the dataset
df = pd.read_csv("train.csv")
df.shape
df.head()
# Out:
#            datetime  season  holiday  workingday              weather   temp  \
# 0    5/2/2012 19:00  Summer        0           1   Clear + Few clouds  22.14
# 1     9/5/2012 4:00    Fall        0           1   Clear + Few clouds  28.70
# 2    1/13/2011 9:00  Spring        0           1   Clear + Few clouds   5.74
# 3  11/18/2011 16:00  Winter        0           1   Clear + Few clouds  13.94
# 4   9/13/2011 13:00    Fall        0           1   Clear + Few clouds  30.34
#
#     atemp  humidity  windspeed
# 0  25.760        77    16.9979
# 1  33.335        79    19.0012
# 2   6.060        50    22.0028
# 3  16.665        29     8.9981
# 4  33.335        51    19.0012

# %%
df2 = pd.read_csv("test.csv")
df2.shape
# Out:
# (2178, 9)

# %%
df.shape
# Out:
# (8708, 9)

# %%
#combining both datasets
frames = [df, df2]
result = pd.concat(frames)
result
# Out:
#               datetime  season  holiday  workingday              weather  \
# 0       5/2/2012 19:00  Summer        0           1   Clear + Few clouds
# 1        9/5/2012 4:00    Fall        0           1   Clear + Few clouds
# 2       1/13/2011 9:00  Spring        0           1   Clear + Few clouds
# 3     11/18/2011 16:00  Winter        0           1   Clear + Few clouds
# 4      9/13/2011 13:00    Fall        0           1   Clear + Few clouds
# ...                ...     ...      ...         ...                  ...
# 2173     3/8/2012 3:00  Spring        0           1   Clear + Few clouds
# 2174   1/12/2012 12:00  Spring        0           1       Mist + Cloudy
# 2175    3/7/2012 22:00  Spring        0           1   Clear + Few clouds
# 2176    5/12/2011 5:00  Summer        0           1   Clear + Few clouds
# 2177   7/18/2012 16:00    Fall        0           1   Clear + Few clouds
#
#        temp   atemp  humidity  windspeed
# 0     22.14  25.760        77    16.9979
# 1     28.70  33.335        79    19.0012
# 2      5.74   6.060        50    22.0028
# 3     13.94  16.665        29     8.9981
# 4     30.34  33.335        51    19.0012
# ...     ...     ...       ...        ...
# 2173  18.86  22.725        63    26.0027
# 2174  13.94  17.425        81     7.0015
# 2175  18.86  22.725        59    19.9995
# 2176  17.22  21.210        94     8.9981
# 2177  30.34  34.850        66    16.9979
#
# [10886 rows x 9 columns]

# %%
result.shape
# Out:
# (10886, 9)

# %%
#unique value of each column
column_list = result.columns.values.tolist()
for column_name in column_list:
      print(result[column_name].unique())
# Out:
# ['5/2/2012 19:00' '9/5/2012 4:00' '1/13/2011 9:00' ... '3/7/2012 22:00'
#  '5/12/2011 5:00' '7/18/2012 16:00']
# ['Summer' 'Fall' 'Spring' 'Winter']
# [0 1]
# [1 0]
# [' Clear + Few clouds' ' Light Snow, Light Rain' ' Mist + Cloudy '
#  ' Heavy Rain + Thunderstorm ']
# [22.14 28.7   5.74 13.94 30.34 33.62 24.6  21.32 27.06 12.3  18.04 18.86
#  25.42 13.12 22.96 26.24 17.22 27.88 36.9  29.52 31.16 10.66 31.98 15.58
#   6.56 19.68 16.4  14.76  9.02 32.8  11.48 20.5   9.84  8.2   7.38 23.78
#  35.26 37.72  3.28  4.1  36.08  1.64  4.92 34.44  0.82  2.46 38.54 39.36
#  41.  ]
# [25.76  33.335  6.06  16.665 12.12  29.545 25.    31.06  15.15  21.97
#  22.725 30.305 26.515 21.21  31.82  39.395 34.85  35.605 18.18  19.695
#  36.365  8.335 32.575 23.485 20.455 34.09  17.425 11.365 14.395 24.24
#  13.635 12.88  28.79  15.91   7.575 18.94  37.12  10.605 37.88   9.09
#  27.275 40.91  42.425 38.635 28.03   5.305  9.85   3.79   6.82  40.15
#   1.515 41.665 43.94   3.03  43.18   4.545  0.76   2.275 44.695 45.455]
# [ 77  79  50  29  51  36  73  68  61  56  62  40  38  39  65  27  88  74
#   93  82  41  49  55  83  80  94  35  48 100  44  33  81  63  75  43  69
#   37  47  23  52  45  58  87  64  25  60  32  67  86  72  53  89  78  66
#   54  42  31  70  26  30  46  59  28  71  76  57  84  16  21  34  24  85
#   91  20  18   0  19  15  13  22   8  90  92  12  14  17  96  10  97]
# [16.9979 19.0012 22.0028  8.9981 12.998   7.0015 11.0014 32.9975 26.0027
#  15.0013 19.9995  6.0032  0.     31.0009 23.9994 36.9974 35.0008 27.9993
#  30.0026 47.9988 39.0007 43.9989 43.0006 56.9969 40.9973 46.0022 51.9987
#  50.0021]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 2177
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  object
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  object
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 850.5+ KB

# %% [markdown]
# # **DATA PREPROCESSING**

# %%
#Separating date and time
result['Dates'] = pd.to_datetime(result['datetime']).dt.date
result['Time'] = pd.to_datetime(result['datetime']).dt.time
result
# Out:
#               datetime  season  holiday  workingday              weather  \
# 0       5/2/2012 19:00  Summer        0           1   Clear + Few clouds
# 1        9/5/2012 4:00    Fall        0           1   Clear + Few clouds
# 2       1/13/2011 9:00  Spring        0           1   Clear + Few clouds
# 3     11/18/2011 16:00  Winter        0           1   Clear + Few clouds
# 4      9/13/2011 13:00    Fall        0           1   Clear + Few clouds
# ...                ...     ...      ...         ...                  ...
# 2173     3/8/2012 3:00  Spring        0           1   Clear + Few clouds
# 2174   1/12/2012 12:00  Spring        0           1       Mist + Cloudy
# 2175    3/7/2012 22:00  Spring        0           1   Clear + Few clouds
# 2176    5/12/2011 5:00  Summer        0           1   Clear + Few clouds
# 2177   7/18/2012 16:00    Fall        0           1   Clear + Few clouds
#
#        temp   atemp  humidity  windspeed       Dates      Time
# 0     22.14  25.760        77    16.9979  2012-05-02  19:00:00
# 1     28.70  33.335        79    19.0012  2012-09-05  04:00:00
# 2      5.74   6.060        50    22.0028  2011-01-13  09:00:00
# 3     13.94  16.665        29     8.9981  2011-11-18  16:00:00
# 4     30.34  33.335        51    19.0012  2011-09-13  13:00:00
# ...     ...     ...       ...        ...         ...       ...
# 2173  18.86  22.725        63    26.0027  2012-03-08  03:00:00
# 2174  13.94  17.425        81     7.0015  2012-01-12  12:00:00
# 2175  18.86  22.725        59    19.9995  2012-03-07  22:00:00
# 2176  17.22  21.210        94     8.9981  2011-05-12  05:00:00
# 2177  30.34  34.850        66    16.9979  2012-07-18  16:00:00
#
# [10886 rows x 11 columns]

# %%
df3 = result
df3
# Out:
#               datetime  season  holiday  workingday              weather  \
# 0       5/2/2012 19:00  Summer        0           1   Clear + Few clouds
# 1        9/5/2012 4:00    Fall        0           1   Clear + Few clouds
# 2       1/13/2011 9:00  Spring        0           1   Clear + Few clouds
# 3     11/18/2011 16:00  Winter        0           1   Clear + Few clouds
# 4      9/13/2011 13:00    Fall        0           1   Clear + Few clouds
# ...                ...     ...      ...         ...                  ...
# 2173     3/8/2012 3:00  Spring        0           1   Clear + Few clouds
# 2174   1/12/2012 12:00  Spring        0           1       Mist + Cloudy
# 2175    3/7/2012 22:00  Spring        0           1   Clear + Few clouds
# 2176    5/12/2011 5:00  Summer        0           1   Clear + Few clouds
# 2177   7/18/2012 16:00    Fall        0           1   Clear + Few clouds
#
#        temp   atemp  humidity  windspeed       Dates      Time
# 0     22.14  25.760        77    16.9979  2012-05-02  19:00:00
# 1     28.70  33.335        79    19.0012  2012-09-05  04:00:00
# 2      5.74   6.060        50    22.0028  2011-01-13  09:00:00
# 3     13.94  16.665        29     8.9981  2011-11-18  16:00:00
# 4     30.34  33.335        51    19.0012  2011-09-13  13:00:00
# ...     ...     ...       ...        ...         ...       ...
# 2173  18.86  22.725        63    26.0027  2012-03-08  03:00:00
# 2174  13.94  17.425        81     7.0015  2012-01-12  12:00:00
# 2175  18.86  22.725        59    19.9995  2012-03-07  22:00:00
# 2176  17.22  21.210        94     8.9981  2011-05-12  05:00:00
# 2177  30.34  34.850        66    16.9979  2012-07-18  16:00:00
#
# [10886 rows x 11 columns]

# %%
#dropping datetime
df3.drop("datetime", axis=1, inplace=True)

# %%
df3
# Out:
#       season  holiday  workingday              weather   temp   atemp  \
# 0     Summer        0           1   Clear + Few clouds  22.14  25.760
# 1       Fall        0           1   Clear + Few clouds  28.70  33.335
# 2     Spring        0           1   Clear + Few clouds   5.74   6.060
# 3     Winter        0           1   Clear + Few clouds  13.94  16.665
# 4       Fall        0           1   Clear + Few clouds  30.34  33.335
# ...      ...      ...         ...                  ...    ...     ...
# 2173  Spring        0           1   Clear + Few clouds  18.86  22.725
# 2174  Spring        0           1       Mist + Cloudy   13.94  17.425
# 2175  Spring        0           1   Clear + Few clouds  18.86  22.725
# 2176  Summer        0           1   Clear + Few clouds  17.22  21.210
# 2177    Fall        0           1   Clear + Few clouds  30.34  34.850
#
#       humidity  windspeed       Dates      Time
# 0           77    16.9979  2012-05-02  19:00:00
# 1           79    19.0012  2012-09-05  04:00:00
# 2           50    22.0028  2011-01-13  09:00:00
# 3           29     8.9981  2011-11-18  16:00:00
# 4           51    19.0012  2011-09-13  13:00:00
# ...        ...        ...         ...       ...
# 2173        63    26.0027  2012-03-08  03:00:00
# 2174        81     7.0015  2012-01-12  12:00:00
# 2175        59    19.9995  2012-03-07  22:00:00
# 2176        94     8.9981  2011-05-12  05:00:00
# 2177        66    16.9979  2012-07-18  16:00:00
#
# [10886 rows x 10 columns]

# %%
df4 = df3
df4
# Out:
#       season  holiday  workingday              weather   temp   atemp  \
# 0     Summer        0           1   Clear + Few clouds  22.14  25.760
# 1       Fall        0           1   Clear + Few clouds  28.70  33.335
# 2     Spring        0           1   Clear + Few clouds   5.74   6.060
# 3     Winter        0           1   Clear + Few clouds  13.94  16.665
# 4       Fall        0           1   Clear + Few clouds  30.34  33.335
# ...      ...      ...         ...                  ...    ...     ...
# 2173  Spring        0           1   Clear + Few clouds  18.86  22.725
# 2174  Spring        0           1       Mist + Cloudy   13.94  17.425
# 2175  Spring        0           1   Clear + Few clouds  18.86  22.725
# 2176  Summer        0           1   Clear + Few clouds  17.22  21.210
# 2177    Fall        0           1   Clear + Few clouds  30.34  34.850
#
#       humidity  windspeed       Dates      Time
# 0           77    16.9979  2012-05-02  19:00:00
# 1           79    19.0012  2012-09-05  04:00:00
# 2           50    22.0028  2011-01-13  09:00:00
# 3           29     8.9981  2011-11-18  16:00:00
# 4           51    19.0012  2011-09-13  13:00:00
# ...        ...        ...         ...       ...
# 2173        63    26.0027  2012-03-08  03:00:00
# 2174        81     7.0015  2012-01-12  12:00:00
# 2175        59    19.9995  2012-03-07  22:00:00
# 2176        94     8.9981  2011-05-12  05:00:00
# 2177        66    16.9979  2012-07-18  16:00:00
#
# [10886 rows x 10 columns]

# %%
#label encoding of weather and season
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df4['weather'])
le_weather_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
df4['weather'] = le.transform(df4['weather'])
print(le_weather_mapping)
# Out:
# {' Clear + Few clouds': 0, ' Heavy Rain + Thunderstorm ': 1, ' Light Snow, Light Rain': 2, ' Mist + Cloudy ': 3}

# %%
df4
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0     Summer        0           1        0  22.14  25.760        77
# 1       Fall        0           1        0  28.70  33.335        79
# 2     Spring        0           1        0   5.74   6.060        50
# 3     Winter        0           1        0  13.94  16.665        29
# 4       Fall        0           1        0  30.34  33.335        51
# ...      ...      ...         ...      ...    ...     ...       ...
# 2173  Spring        0           1        0  18.86  22.725        63
# 2174  Spring        0           1        3  13.94  17.425        81
# 2175  Spring        0           1        0  18.86  22.725        59
# 2176  Summer        0           1        0  17.22  21.210        94
# 2177    Fall        0           1        0  30.34  34.850        66
#
#       windspeed       Dates      Time
# 0       16.9979  2012-05-02  19:00:00
# 1       19.0012  2012-09-05  04:00:00
# 2       22.0028  2011-01-13  09:00:00
# 3        8.9981  2011-11-18  16:00:00
# 4       19.0012  2011-09-13  13:00:00
# ...         ...         ...       ...
# 2173    26.0027  2012-03-08  03:00:00
# 2174     7.0015  2012-01-12  12:00:00
# 2175    19.9995  2012-03-07  22:00:00
# 2176     8.9981  2011-05-12  05:00:00
# 2177    16.9979  2012-07-18  16:00:00
#
# [10886 rows x 10 columns]

# %%
le.fit(df4['season'])
le_weather_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
df4['season'] = le.transform(df4['season'])
print(le_weather_mapping)
df4
# Out:
# {'Fall': 0, 'Spring': 1, 'Summer': 2, 'Winter': 3}
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          2        0           1        0  22.14  25.760        77
# 1          0        0           1        0  28.70  33.335        79
# 2          1        0           1        0   5.74   6.060        50
# 3          3        0           1        0  13.94  16.665        29
# 4          0        0           1        0  30.34  33.335        51
# ...      ...      ...         ...      ...    ...     ...       ...
# 2173       1        0           1        0  18.86  22.725        63
# 2174       1        0           1        3  13.94  17.425        81
# 2175       1        0           1        0  18.86  22.725        59
# 2176       2        0           1        0  17.22  21.210        94
# 2177       0        0           1        0  30.34  34.850        66
#
#       windspeed       Dates      Time
# 0       16.9979  2012-05-02  19:00:00
# 1       19.0012  2012-09-05  04:00:00
# 2       22.0028  2011-01-13  09:00:00
# 3        8.9981  2011-11-18  16:00:00
# 4       19.0012  2011-09-13  13:00:00
# ...         ...         ...       ...
# 2173    26.0027  2012-03-08  03:00:00
# 2174     7.0015  2012-01-12  12:00:00
# 2175    19.9995  2012-03-07  22:00:00
# 2176     8.9981  2011-05-12  05:00:00
# 2177    16.9979  2012-07-18  16:00:00
#
# [10886 rows x 10 columns]

# %%
#converting date to int
df4["Dates"] = pd.to_datetime(df4["Dates"]).dt.strftime("%Y%m%d")
df4
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          2        0           1        0  22.14  25.760        77
# 1          0        0           1        0  28.70  33.335        79
# 2          1        0           1        0   5.74   6.060        50
# 3          3        0           1        0  13.94  16.665        29
# 4          0        0           1        0  30.34  33.335        51
# ...      ...      ...         ...      ...    ...     ...       ...
# 2173       1        0           1        0  18.86  22.725        63
# 2174       1        0           1        3  13.94  17.425        81
# 2175       1        0           1        0  18.86  22.725        59
# 2176       2        0           1        0  17.22  21.210        94
# 2177       0        0           1        0  30.34  34.850        66
#
#       windspeed     Dates      Time
# 0       16.9979  20120502  19:00:00
# 1       19.0012  20120905  04:00:00
# 2       22.0028  20110113  09:00:00
# 3        8.9981  20111118  16:00:00
# 4       19.0012  20110913  13:00:00
# ...         ...       ...       ...
# 2173    26.0027  20120308  03:00:00
# 2174     7.0015  20120112  12:00:00
# 2175    19.9995  20120307  22:00:00
# 2176     8.9981  20110512  05:00:00
# 2177    16.9979  20120718  16:00:00
#
# [10886 rows x 10 columns]

# %%
#combining both datasets
frames = [df, df2]
result = pd.concat(frames)
result
# Out:
#               datetime  season  holiday  workingday              weather  \
# 0       5/2/2012 19:00  Summer        0           1   Clear + Few clouds
# 1        9/5/2012 4:00    Fall        0           1   Clear + Few clouds
# 2       1/13/2011 9:00  Spring        0           1   Clear + Few clouds
# 3     11/18/2011 16:00  Winter        0           1   Clear + Few clouds
# 4      9/13/2011 13:00    Fall        0           1   Clear + Few clouds
# ...                ...     ...      ...         ...                  ...
# 2173     3/8/2012 3:00  Spring        0           1   Clear + Few clouds
# 2174   1/12/2012 12:00  Spring        0           1       Mist + Cloudy
# 2175    3/7/2012 22:00  Spring        0           1   Clear + Few clouds
# 2176    5/12/2011 5:00  Summer        0           1   Clear + Few clouds
# 2177   7/18/2012 16:00    Fall        0           1   Clear + Few clouds
#
#        temp   atemp  humidity  windspeed
# 0     22.14  25.760        77    16.9979
# 1     28.70  33.335        79    19.0012
# 2      5.74   6.060        50    22.0028
# 3     13.94  16.665        29     8.9981
# 4     30.34  33.335        51    19.0012
# ...     ...     ...       ...        ...
# 2173  18.86  22.725        63    26.0027
# 2174  13.94  17.425        81     7.0015
# 2175  18.86  22.725        59    19.9995
# 2176  17.22  21.210        94     8.9981
# 2177  30.34  34.850        66    16.9979
#
# [10886 rows x 9 columns]

# %%
#converting time to int
df4["Time"] = pd.to_datetime(result["datetime"]).dt.strftime("%H")
df4
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          2        0           1        0  22.14  25.760        77
# 1          0        0           1        0  28.70  33.335        79
# 2          1        0           1        0   5.74   6.060        50
# 3          3        0           1        0  13.94  16.665        29
# 4          0        0           1        0  30.34  33.335        51
# ...      ...      ...         ...      ...    ...     ...       ...
# 2173       1        0           1        0  18.86  22.725        63
# 2174       1        0           1        3  13.94  17.425        81
# 2175       1        0           1        0  18.86  22.725        59
# 2176       2        0           1        0  17.22  21.210        94
# 2177       0        0           1        0  30.34  34.850        66
#
#       windspeed     Dates Time
# 0       16.9979  20120502   19
# 1       19.0012  20120905   04
# 2       22.0028  20110113   09
# 3        8.9981  20111118   16
# 4       19.0012  20110913   13
# ...         ...       ...  ...
# 2173    26.0027  20120308   03
# 2174     7.0015  20120112   12
# 2175    19.9995  20120307   22
# 2176     8.9981  20110512   05
# 2177    16.9979  20120718   16
#
# [10886 rows x 10 columns]

# %%
#since month and year makes more sense then date 
#extracting month and year from date
df4["Month"] = pd.to_datetime(result["datetime"]).dt.strftime("%m")
df4["Year"] = pd.to_datetime(result["datetime"]).dt.strftime("%Y")
df4
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          2        0           1        0  22.14  25.760        77
# 1          0        0           1        0  28.70  33.335        79
# 2          1        0           1        0   5.74   6.060        50
# 3          3        0           1        0  13.94  16.665        29
# 4          0        0           1        0  30.34  33.335        51
# ...      ...      ...         ...      ...    ...     ...       ...
# 2173       1        0           1        0  18.86  22.725        63
# 2174       1        0           1        3  13.94  17.425        81
# 2175       1        0           1        0  18.86  22.725        59
# 2176       2        0           1        0  17.22  21.210        94
# 2177       0        0           1        0  30.34  34.850        66
#
#       windspeed     Dates Time Month  Year
# 0       16.9979  20120502   19    05  2012
# 1       19.0012  20120905   04    09  2012
# 2       22.0028  20110113   09    01  2011
# 3        8.9981  20111118   16    11  2011
# 4       19.0012  20110913   13    09  2011
# ...         ...       ...  ...   ...   ...
# 2173    26.0027  20120308   03    03  2012
# 2174     7.0015  20120112   12    01  2012
# 2175    19.9995  20120307   22    03  2012
# 2176     8.9981  20110512   05    05  2011
# 2177    16.9979  20120718   16    07  2012
#
# [10886 rows x 12 columns]

# %%
#dropping datetime
df4.drop("Dates", axis=1, inplace=True)

# %%
df4
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          2        0           1        0  22.14  25.760        77
# 1          0        0           1        0  28.70  33.335        79
# 2          1        0           1        0   5.74   6.060        50
# 3          3        0           1        0  13.94  16.665        29
# 4          0        0           1        0  30.34  33.335        51
# ...      ...      ...         ...      ...    ...     ...       ...
# 2173       1        0           1        0  18.86  22.725        63
# 2174       1        0           1        3  13.94  17.425        81
# 2175       1        0           1        0  18.86  22.725        59
# 2176       2        0           1        0  17.22  21.210        94
# 2177       0        0           1        0  30.34  34.850        66
#
#       windspeed Time Month  Year
# 0       16.9979   19    05  2012
# 1       19.0012   04    09  2012
# 2       22.0028   09    01  2011
# 3        8.9981   16    11  2011
# 4       19.0012   13    09  2011
# ...         ...  ...   ...   ...
# 2173    26.0027   03    03  2012
# 2174     7.0015   12    01  2012
# 2175    19.9995   22    03  2012
# 2176     8.9981   05    05  2011
# 2177    16.9979   16    07  2012
#
# [10886 rows x 11 columns]

# %%
df4['Year'] = df4['Year'].astype(int)/2000
df4
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          2        0           1        0  22.14  25.760        77
# 1          0        0           1        0  28.70  33.335        79
# 2          1        0           1        0   5.74   6.060        50
# 3          3        0           1        0  13.94  16.665        29
# 4          0        0           1        0  30.34  33.335        51
# ...      ...      ...         ...      ...    ...     ...       ...
# 2173       1        0           1        0  18.86  22.725        63
# 2174       1        0           1        3  13.94  17.425        81
# 2175       1        0           1        0  18.86  22.725        59
# 2176       2        0           1        0  17.22  21.210        94
# 2177       0        0           1        0  30.34  34.850        66
#
#       windspeed Time Month    Year
# 0       16.9979   19    05  1.0060
# 1       19.0012   04    09  1.0060
# 2       22.0028   09    01  1.0055
# 3        8.9981   16    11  1.0055
# 4       19.0012   13    09  1.0055
# ...         ...  ...   ...     ...
# 2173    26.0027   03    03  1.0060
# 2174     7.0015   12    01  1.0060
# 2175    19.9995   22    03  1.0060
# 2176     8.9981   05    05  1.0055
# 2177    16.9979   16    07  1.0060
#
# [10886 rows x 11 columns]

# %%
df5 = df4

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 2177
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      10886 non-null  int32
#  1   holiday     10886 non-null  int64
#  2   workingday  10886 non-null  int64
#  3   weather     10886 non-null  int32
#  4   temp        10886 non-null  float64
#  5   atemp       10886 non-null  float64
#  6   humidity    10886 non-null  int64
#  7   windspeed   10886 non-null  float64
#  8   Time        10886 non-null  object
#  9   Month       10886 non-null  object
#  10  Year        10886 non-null  float64
# dtypes: float64(4), int32(2), int64(3), object(2)
# memory usage: 935.5+ KB

# %%
df5['Time'] = pd.to_numeric(df5['Time'])
df5['Month'] = pd.to_numeric(df5['Month'])
df5['Year'] = pd.to_numeric(df5['Year'])
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 2177
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      10886 non-null  int32
#  1   holiday     10886 non-null  int64
#  2   workingday  10886 non-null  int64
#  3   weather     10886 non-null  int32
#  4   temp        10886 non-null  float64
#  5   atemp       10886 non-null  float64
#  6   humidity    10886 non-null  int64
#  7   windspeed   10886 non-null  float64
#  8   Time        10886 non-null  int64
#  9   Month       10886 non-null  int64
#  10  Year        10886 non-null  float64
# dtypes: float64(4), int32(2), int64(5)
# memory usage: 935.5 KB

# %%
#Extracting segments

#Using k-means clustering analysis
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12)).fit(df5)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# K-means clustering 

kmeans = KMeans(n_clusters=3, init='k-means++', random_state=0).fit(df3)
df3['cluster_num'] = kmeans.labels_ #adding to df
print (kmeans.labels_) #Label assigned for each data point
print (kmeans.inertia_) #gives within-cluster sum of squares. 
print(kmeans.n_iter_) #number of iterations that k-means algorithm runs to get a minimum within-cluster sum of squares
print(kmeans.cluster_centers_) #Location of the centroids on each cluster.
# Out:
# [1 1 2 ... 2 1 0]
# 3177917.639461683
# 10
# [[1.10989387e+00 2.36220472e-02 7.05922629e-01 5.98082848e-01
#   2.83392674e+01 3.24519685e+01 4.89171517e+01 1.32285410e+01
#   1.41170832e+01 6.91338583e+00 1.00576806e+00]
#  [1.58457812e+00 2.96729915e-02 6.69559952e-01 1.34053290e+00
#   1.96460678e+01 2.31936486e+01 7.94701252e+01 1.02252292e+01
#   9.39402503e+00 7.13463868e+00 1.00573365e+00]
#  [1.74759216e+00 3.15509797e-02 6.75190966e-01 6.08767851e-01
#   1.33269744e+01 1.58803421e+01 4.55376951e+01 1.66183542e+01
#   1.25765526e+01 5.13251411e+00 1.00576287e+00]]

# %%
#To see each cluster size
from collections import Counter
Counter(kmeans.labels_)
# Out:
# Counter({1: 4956, 2: 3008, 0: 2922})

# %%
#Visulazing clusters
sns.scatterplot(data=df5, x="season", y="Time", hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()

# %%
#Visulazing clusters
sns.scatterplot(data=df5, x="temp", y="Time", hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()

# %%
#Visulazing clusters
sns.scatterplot(data=df5, x="humidity", y="temp", hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()

# %%
result.to_csv("combined_data")
df5.to_csv("cleaned_data")

# %%
#Visulazing clusters
sns.scatterplot(data=df5, x="holiday", y="Time", hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()

# %%
#Visulazing clusters
sns.scatterplot(data=df5, x="season", y="temp", hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()

# %%
#Visulazing clusters
sns.scatterplot(data=df5, x="season", y="atemp", hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()

# %%
#Visulazing clusters
sns.scatterplot(data=df5, x="weather", y="Time", hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()

# %% [markdown]
# # **Describing Segments**

# %%
from statsmodels.graphics.mosaicplot import mosaic
from itertools import product

crosstab =pd.crosstab(df5['cluster_num'],df5['season'])
#Reordering cols
crosstab = crosstab[[0,1,2,3]]
crosstab
# Out:
# season          0     1     2     3
# cluster_num
# 0            1385   147  1071   319
# 1            1331   888  1247  1490
# 2              17  1651   415   925

# %%
#MOSAIC PLOT
plt.rcParams['figure.figsize'] = (7,5)
mosaic(crosstab.stack())
plt.show()

# %%
crosstab1 =pd.crosstab(df5['cluster_num'],df5['weather'])
#Reordering cols
crosstab1 = crosstab1[[0,1,2,3]]
crosstab1
# Out:
# weather         0  1    2     3
# cluster_num
# 0            2323  0   53   546
# 1            2493  1  743  1719
# 2            2376  0   63   569

# %%
#MOSAIC PLOT
plt.rcParams['figure.figsize'] = (7,5)
mosaic(crosstab1.stack())
plt.show()

# %%
crosstab2 =pd.crosstab(df5['cluster_num'],df5['Time'])
#Reordering cols
crosstab2 = crosstab2[[0,1,2,3,4,5,6,7]]
crosstab2
# Out:
# Time           0    1    2    3    4    5    6    7
# cluster_num
# 0             64   57   43   33   26   23   26   38
# 1            282  296  312  318  339  337  340  323
# 2            109  101   93   82   77   92   89   94

# %%
crosstab3 =pd.crosstab(df5['cluster_num'],df5['Time'])
#Reordering cols
crosstab3 = crosstab3[[8,9,10,11,12,13,14,15]]
crosstab3
# Out:
# Time          8    9    10   11   12   13   14   15
# cluster_num
# 0             69  106  138  175  194  214  221  224
# 1            283  223  182  135  105   86   80   80
# 2            103  126  135  145  157  156  155  152

# %%
crosstab4 =pd.crosstab(df5['cluster_num'],df5['Time'])
#Reordering cols
crosstab4 = crosstab4[[16,17,18,19,20,21,22,23]]
crosstab4
# Out:
# Time          16   17   18   19   20   21   22   23
# cluster_num
# 0            217  213  190  167  147  126  115   96
# 1             83   95  110  139  161  194  212  241
# 2            156  148  156  150  148  136  129  119

# %%
#box plot for age

sns.boxplot(x="cluster_num", y="Time", data=df5)
# Out:
# <AxesSubplot:xlabel='cluster_num', ylabel='Time'>
